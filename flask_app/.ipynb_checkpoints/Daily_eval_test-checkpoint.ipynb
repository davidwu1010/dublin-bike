# %%
import sys
sys.path.insert(1, "/Users/pie_trick/Desktop/Semester2/SWengineering/dublin-bikes")    
import pymysql

# %%
import datetime
import pytz
from sqlalchemy import create_engine
from models.schemas import Base
from config import MySQL
import pandas as pd
import numpy as np
import joblib

def bike_predict_daily(number_input):
    host = MySQL.host
    user = MySQL.username
    password = MySQL.password
    database = MySQL.database

    #Create SQL engine to connect to database
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')
    Base.metadata.create_all(engine)
    
    #Calibrate the query ata amount by current time
    hour_left = 1728 + (23 - datetime.datetime.utcnow().hour)
    
    query_bike = "SELECT * \
                  FROM development.dublin_bike\
                  WHERE number = %(number)s\
                  ORDER BY scraping_time desc\
                  LIMIT %(size)s;"

    query_weather = "SELECT * \
                    FROM development.current_weather\
                    WHERE stationNum = %(number)s \
                    ORDER BY datetime desc\
                    LIMIT %(size)s;"

    bike_df = pd.read_sql_query(sql=query_bike, con=engine, params={'number': number_input, 'size': hour_left},parse_dates=['scraping_time'])
    weather_df = pd.read_sql_query(sql=query_weather, con=engine, params={'number': number_input,'size': hour_left}, parse_dates=['scraping_time'])

    '''Add label'''
    def labeling_eval(df):
        df["available_bike_ratio"] = df['available_bike'] / df['bike_stand']
        return df

    '''Merge weather and bike table'''
    def merge_df(bike_df, weather_df):
        combined_df = pd.merge(bike_df, weather_df, how='inner',
                               left_on=['number', 'scraping_time'],
                               right_on=['stationNum', 'datetime'],
                               suffixes=('_bike', '_weather'))
        return combined_df

    '''Extract hour of the day'''
    def datetime_conversion(df, df_col):
        df['hour'] = df[df_col].dt.hour
        return df

    '''Feature engineeer the time feature to cyclic sine cosine representation'''
    def time_transform(df, col, max_val):
        df[col + '_sin'] = np.sin(2 * np.pi * df[col] / max_val)
        df[col + '_cos'] = np.cos(2 * np.pi * df[col] / max_val)
        df = df.drop([col], axis=1)
        return df

    '''Drop redundant columns'''
    def data_cleaning(df):
        pd.set_option('display.max_columns', 500)
        col_to_drop = ['address', 'site_names', 'bonus', 'last_update', 'datetime', 'icon', 'lon', 'lat', 'stationNum',
                       'available_bike_stand', 'description', 'status', 'sunset']
        df = df.drop(col_to_drop, axis=1)
        df = df.drop_duplicates().reset_index()
        df = df.drop(['index'], axis=1)
        df = df.drop(['available_bike'], axis=1)

        return df

    '''Convert data type'''
    def data_type_conversion(df):
        df['banking'] = df['banking'].astype('int32')
        df['code'] = df['code'].astype('int32') // 100
        df['temperature'] = df['temperature'].astype('float64')
        return df


    bike_df = labeling_eval(bike_df)
    combined_df = merge_df(bike_df, weather_df)

    combined_df = data_type_conversion(combined_df)
    combined_df = data_cleaning(combined_df)
    combined_df = datetime_conversion(combined_df, "scraping_time")
    daily_df = combined_df.resample('H', on='scraping_time').mean().reset_index()
    weekday = daily_df['weekday'].astype('int32')
    hour = daily_df['hour'].astype('int32')
    daily_df = time_transform(daily_df, 'weekday', 7)
    daily_df = time_transform(daily_df, 'hour', 23)
    daily_df.drop('scraping_time', axis=1, inplace =True)
    total_bike_stand = combined_df.loc[0,'bike_stand']

    #Inference with model
    model_name = 'lgbm_model_daily.pkl'
    model = joblib.load(model_name)
    y_prediction = model.predict(daily_df)

    #Reformat the data to json format
    data = pd.DataFrame({'number': daily_df['number'], 'hour': hour, 'weekday': weekday,
                         'bike_predict':y_prediction *total_bike_stand})
    days = {1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat', 7: 'Sun'}
    data['weekday'] = data['weekday'].apply(lambda x: days[x])
    data = data.set_index(['weekday'])
    predict_daily_json = {}

    #Combine json data
    for i in data.index:
        predict_daily_json[i] = data.loc[i, ['number','hour','bike_predict']].to_dict(orient='records')

    return predict_daily_json

# %%
bike_predict_daily(8)
# Out:
# {'Fri': [{'number': 8, 'hour': 20, 'bike_predict': 12.01681352631909},
#   {'number': 8, 'hour': 21, 'bike_predict': 11.968368249356546},
#   {'number': 8, 'hour': 22, 'bike_predict': 12.362290105364115},
#   {'number': 8, 'hour': 23, 'bike_predict': 13.189184693909903}],
#  'Sat': [{'number': 8, 'hour': 0, 'bike_predict': 12.409606346379153},
#   {'number': 8, 'hour': 1, 'bike_predict': 13.008146773343247},
#   {'number': 8, 'hour': 2, 'bike_predict': 12.908500780110804},
#   {'number': 8, 'hour': 3, 'bike_predict': 13.168140655730275},
#   {'number': 8, 'hour': 4, 'bike_predict': 13.758778733698858},
#   {'number': 8, 'hour': 5, 'bike_predict': 13.824803476296854},
#   {'number': 8, 'hour': 6, 'bike_predict': 13.740364003997296},
#   {'number': 8, 'hour': 7, 'bike_predict': 13.685644211973397},
#   {'number': 8, 'hour': 8, 'bike_predict': 13.200754118489737},
#   {'number': 8, 'hour': 9, 'bike_predict': 13.40218724395957},
#   {'number': 8, 'hour': 10, 'bike_predict': 13.979741250141183},
#   {'number': 8, 'hour': 11, 'bike_predict': 13.952477759915476},
#   {'number': 8, 'hour': 12, 'bike_predict': 14.084141740351587},
#   {'number': 8, 'hour': 13, 'bike_predict': 13.99557726710007},
#   {'number': 8, 'hour': 14, 'bike_predict': 13.765389564890366},
#   {'number': 8, 'hour': 15, 'bike_predict': 13.9000792774452},
#   {'number': 8, 'hour': 16, 'bike_predict': 13.901920293952397},
#   {'number': 8, 'hour': 17, 'bike_predict': 13.868004088399427},
#   {'number': 8, 'hour': 18, 'bike_predict': 13.87205195131604},
#   {'number': 8, 'hour': 19, 'bike_predict': 13.887157042210175},
#   {'number': 8, 'hour': 20, 'bike_predict': 13.6623317423873},
#   {'number': 8, 'hour': 21, 'bike_predict': 13.53236807868545},
#   {'number': 8, 'hour': 22, 'bike_predict': 13.646566510134042},
#   {'number': 8, 'hour': 23, 'bike_predict': 13.334712483099977}],
#  'Sun': [{'number': 8, 'hour': 0, 'bike_predict': 12.840809423364234},
#   {'number': 8, 'hour': 1, 'bike_predict': 12.5889847883244},
#   {'number': 8, 'hour': 2, 'bike_predict': 12.908280653307818},
#   {'number': 8, 'hour': 3, 'bike_predict': 13.013325197725425},
#   {'number': 8, 'hour': 4, 'bike_predict': 13.025621113028594},
#   {'number': 8, 'hour': 5, 'bike_predict': 13.816168196423028},
#   {'number': 8, 'hour': 6, 'bike_predict': 13.266990826222724},
#   {'number': 8, 'hour': 7, 'bike_predict': 13.299039403296556},
#   {'number': 8, 'hour': 8, 'bike_predict': 13.4543077835735},
#   {'number': 8, 'hour': 9, 'bike_predict': 13.759604985368924},
#   {'number': 8, 'hour': 10, 'bike_predict': 12.552400137267679},
#   {'number': 8, 'hour': 11, 'bike_predict': 12.483105609971323},
#   {'number': 8, 'hour': 12, 'bike_predict': 12.789783329909545},
#   {'number': 8, 'hour': 13, 'bike_predict': 12.796786297188499},
#   {'number': 8, 'hour': 14, 'bike_predict': 12.704529490580875},
#   {'number': 8, 'hour': 15, 'bike_predict': 12.431941071794252},
#   {'number': 8, 'hour': 16, 'bike_predict': 12.885153579788769},
#   {'number': 8, 'hour': 17, 'bike_predict': 12.936512984300927},
#   {'number': 8, 'hour': 18, 'bike_predict': 13.089865139220969},
#   {'number': 8, 'hour': 19, 'bike_predict': 13.222930875171553},
#   {'number': 8, 'hour': 20, 'bike_predict': 12.875438042269355},
#   {'number': 8, 'hour': 21, 'bike_predict': 13.512574169035666},
#   {'number': 8, 'hour': 22, 'bike_predict': 13.747329848882725},
#   {'number': 8, 'hour': 23, 'bike_predict': 13.663704566809344}],
#  'Mon': [{'number': 8, 'hour': 0, 'bike_predict': 12.865449983570883},
#   {'number': 8, 'hour': 1, 'bike_predict': 12.946529641578465},
#   {'number': 8, 'hour': 2, 'bike_predict': 13.11044622522181},
#   {'number': 8, 'hour': 3, 'bike_predict': 13.207517059514188},
#   {'number': 8, 'hour': 4, 'bike_predict': 13.810093339096765},
#   {'number': 8, 'hour': 5, 'bike_predict': 14.40206892835025},
#   {'number': 8, 'hour': 6, 'bike_predict': 17.082412127186604},
#   {'number': 8, 'hour': 7, 'bike_predict': 14.968726547991956},
#   {'number': 8, 'hour': 8, 'bike_predict': 15.260873439428355},
#   {'number': 8, 'hour': 9, 'bike_predict': 13.177730560734604},
#   {'number': 8, 'hour': 10, 'bike_predict': 14.566089942473791},
#   {'number': 8, 'hour': 11, 'bike_predict': 14.496660799417011},
#   {'number': 8, 'hour': 12, 'bike_predict': 14.697035534188064},
#   {'number': 8, 'hour': 13, 'bike_predict': 13.686512282920553},
#   {'number': 8, 'hour': 14, 'bike_predict': 13.59501360046641},
#   {'number': 8, 'hour': 15, 'bike_predict': 13.890781282737002},
#   {'number': 8, 'hour': 16, 'bike_predict': 13.669720789517548},
#   {'number': 8, 'hour': 17, 'bike_predict': 14.097391296201822},
#   {'number': 8, 'hour': 18, 'bike_predict': 14.599921660844679},
#   {'number': 8, 'hour': 19, 'bike_predict': 14.08493230952279},
#   {'number': 8, 'hour': 20, 'bike_predict': 12.651362826121026},
#   {'number': 8, 'hour': 21, 'bike_predict': 15.518744719983337},
#   {'number': 8, 'hour': 22, 'bike_predict': 15.172743064346289},
#   {'number': 8, 'hour': 23, 'bike_predict': 15.289066381673516}],
#  'Tue': [{'number': 8, 'hour': 0, 'bike_predict': 16.534276286993716},
#   {'number': 8, 'hour': 1, 'bike_predict': 16.732142192994505},
#   {'number': 8, 'hour': 2, 'bike_predict': 16.690000152118618},
#   {'number': 8, 'hour': 3, 'bike_predict': 16.715927211983235},
#   {'number': 8, 'hour': 4, 'bike_predict': 16.640534301650497},
#   {'number': 8, 'hour': 5, 'bike_predict': 16.734934645144637},
#   {'number': 8, 'hour': 6, 'bike_predict': 18.922266417393367},
#   {'number': 8, 'hour': 7, 'bike_predict': 21.200670031169285},
#   {'number': 8, 'hour': 8, 'bike_predict': 17.34302784565437},
#   {'number': 8, 'hour': 9, 'bike_predict': 16.047219706809397},
#   {'number': 8, 'hour': 10, 'bike_predict': 15.946606850846264},
#   {'number': 8, 'hour': 11, 'bike_predict': 13.950805063588076},
#   {'number': 8, 'hour': 12, 'bike_predict': 13.622699350483463},
#   {'number': 8, 'hour': 13, 'bike_predict': 13.756824527528805},
#   {'number': 8, 'hour': 14, 'bike_predict': 13.121703689346221},
#   {'number': 8, 'hour': 15, 'bike_predict': 13.417354416678887},
#   {'number': 8, 'hour': 16, 'bike_predict': 13.59715587999478},
#   {'number': 8, 'hour': 17, 'bike_predict': 14.235965461652425},
#   {'number': 8, 'hour': 18, 'bike_predict': 14.690145811901413},
#   {'number': 8, 'hour': 19, 'bike_predict': 16.12938955205749},
#   {'number': 8, 'hour': 20, 'bike_predict': 16.976286729978952},
#   {'number': 8, 'hour': 21, 'bike_predict': 18.53436802119601},
#   {'number': 8, 'hour': 22, 'bike_predict': 18.396965103764394},
#   {'number': 8, 'hour': 23, 'bike_predict': 19.404669034886105}],
#  'Wed': [{'number': 8, 'hour': 0, 'bike_predict': 16.66348410506172},
#   {'number': 8, 'hour': 1, 'bike_predict': 17.010319130827536},
#   {'number': 8, 'hour': 2, 'bike_predict': 17.44902553986169},
#   {'number': 8, 'hour': 3, 'bike_predict': 18.02654911377832},
#   {'number': 8, 'hour': 4, 'bike_predict': 17.538545244751894},
#   {'number': 8, 'hour': 5, 'bike_predict': 17.658055930065554},
#   {'number': 8, 'hour': 6, 'bike_predict': 17.434176298521898},
#   {'number': 8, 'hour': 7, 'bike_predict': 18.647079728625304},
#   {'number': 8, 'hour': 8, 'bike_predict': 12.457905707903562},
#   {'number': 8, 'hour': 9, 'bike_predict': 11.287919702732152},
#   {'number': 8, 'hour': 10, 'bike_predict': 11.330550373677514},
#   {'number': 8, 'hour': 11, 'bike_predict': 11.14602526796111},
#   {'number': 8, 'hour': 12, 'bike_predict': 11.852295958568803},
#   {'number': 8, 'hour': 13, 'bike_predict': 11.911327353059795},
#   {'number': 8, 'hour': 14, 'bike_predict': 11.292504486578649},
#   {'number': 8, 'hour': 15, 'bike_predict': 11.418041706986843},
#   {'number': 8, 'hour': 16, 'bike_predict': 11.257437773449553},
#   {'number': 8, 'hour': 17, 'bike_predict': 11.206862739291534},
#   {'number': 8, 'hour': 18, 'bike_predict': 11.225429322602217},
#   {'number': 8, 'hour': 19, 'bike_predict': 10.900068510356554},
#   {'number': 8, 'hour': 20, 'bike_predict': 11.385039790797245},
#   {'number': 8, 'hour': 21, 'bike_predict': 11.740918592027212},
#   {'number': 8, 'hour': 22, 'bike_predict': 11.983335105119806},
#   {'number': 8, 'hour': 23, 'bike_predict': 13.427632361274366}],
#  'Thu': [{'number': 8, 'hour': 0, 'bike_predict': 13.478192534143158},
#   {'number': 8, 'hour': 1, 'bike_predict': 13.550057350795239},
#   {'number': 8, 'hour': 2, 'bike_predict': 13.655087316089618},
#   {'number': 8, 'hour': 3, 'bike_predict': 14.05583038227012},
#   {'number': 8, 'hour': 4, 'bike_predict': 16.08117800861521},
#   {'number': 8, 'hour': 5, 'bike_predict': 14.784898904949834},
#   {'number': 8, 'hour': 6, 'bike_predict': 14.143522491275625},
#   {'number': 8, 'hour': 7, 'bike_predict': 14.058085087333266},
#   {'number': 8, 'hour': 8, 'bike_predict': 13.397399318388572},
#   {'number': 8, 'hour': 9, 'bike_predict': 12.168206501746665},
#   {'number': 8, 'hour': 10, 'bike_predict': 12.175415447629543},
#   {'number': 8, 'hour': 11, 'bike_predict': 11.575170072800377},
#   {'number': 8, 'hour': 12, 'bike_predict': 12.419217499975467},
#   {'number': 8, 'hour': 13, 'bike_predict': 12.417310433434823},
#   {'number': 8, 'hour': 14, 'bike_predict': 12.485349485505363},
#   {'number': 8, 'hour': 15, 'bike_predict': 12.484754256476528},
#   {'number': 8, 'hour': 16, 'bike_predict': 12.554209964445503},
#   {'number': 8, 'hour': 17, 'bike_predict': 12.608717088872512},
#   {'number': 8, 'hour': 18, 'bike_predict': 12.518141199152641},
#   {'number': 8, 'hour': 19, 'bike_predict': 13.235468598577544},
#   {'number': 8, 'hour': 20, 'bike_predict': 12.540237147352185}]}

# %%
datetime.datetime.utcnow().hour
# Out:
# 20
